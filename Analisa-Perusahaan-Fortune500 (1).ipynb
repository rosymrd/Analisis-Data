# %%
! whoami
# Out:
# lenovo_loq

# %%
! hostname
# Out:
# TI3A-Mila-Rosita-Dewi

# %%
! date
# Out:
# Thu May  7 19:43:46 WIB 2026

# %% [markdown]
# # Tugas: Menganalisa Perusahaan Fortune 500

# %% [markdown]
# Fortune 500 adalah sebuah daftar 500 perusahaan yang diterbitkan setiap tahun oleh majalah bisnis **Fortune**. Daftar ini berisi 500 perusahaan publik terbesar di Amerika Serikat berdasarkan pendapatan kotor mereka dalam tahun fiskal sebelumnya. Dalam daftar ini, perusahaan-perusahaan tersebut diurutkan berdasarkan pendapatan tahunan mereka, dan merupakan indikator utama dalam mengukur keberhasilan dan ukuran perusahaan di pasar Amerika Serikat.
#
# Daftar Fortune 500 sering digunakan sebagai referensi oleh para pelaku bisnis, investor, dan pengamat ekonomi untuk mengetahui tren dalam dunia korporasi, serta untuk memperoleh wawasan tentang kekuatan dan stabilitas perusahaan-perusahaan terkemuka di Amerika Serikat.

# %% [markdown]
# ## Persiapan

# %% [markdown]
# Pastikan telah mengerjakan **latihan**, karena memelukan user dan database yang telah dibuat pada latihan.

# %% [markdown]
# ## Menghubungkan Jupyter Notebook ke Database

# %%
# %load_ext sql
# %sql postgresql://mila:123456@localhost:5432/training
# %config SqlMagic.style = '_DEPRECATED_DEFAULT'
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
# %%sql
#
# SELECT version();
# Out:
#  * postgresql://mila:***@localhost:5432/training
# 1 rows affected.
# [('PostgreSQL 16.13 (Ubuntu 16.13-0ubuntu0.24.04.1) on x86_64-pc-linux-gnu, compiled by gcc (Ubuntu 13.3.0-6ubuntu2~24.04.1) 13.3.0, 64-bit',)]

# %% [markdown]
# ## Membuat Tabel

# %%
# %%sql
# DROP TABLE IF EXISTS fortune500
# Out:
#  * postgresql://mila:***@localhost:5432/training
# Done.
# []

# %%
# %%sql
# CREATE TABLE IF NOT EXISTS fortune500 (
#   rank INTEGER,
#   title VARCHAR(100),
#   name VARCHAR(100),
#   ticker VARCHAR(100),
#   url VARCHAR(255),
#   hq VARCHAR(100),
#   sector VARCHAR(50),
#   industry VARCHAR(50),
#   employees INTEGER,
#   revenues INTEGER,
#   revenues_change REAL,
#   profits NUMERIC,
#   profits_change REAL,
#   assets NUMERIC,
#   equity NUMERIC
#
# );
# Out:
#  * postgresql://mila:***@localhost:5432/training
# (psycopg2.errors.InsufficientPrivilege) permission denied for schema public
# LINE 1: CREATE TABLE IF NOT EXISTS fortune500 (
#                                    ^
#
# [SQL: CREATE TABLE IF NOT EXISTS fortune500 (
#   rank INTEGER,
#   title VARCHAR(100),
#   name VARCHAR(100),
#   ticker VARCHAR(100),
#   url VARCHAR(255),
#   hq VARCHAR(100),
#   sector VARCHAR(50),
#   industry VARCHAR(50),
#   employees INTEGER,
#   revenues INTEGER,
#   revenues_change REAL,
#   profits NUMERIC,
#   profits_change REAL,
#   assets NUMERIC,
#   equity NUMERIC
#
# );]
# (Background on this error at: https://sqlalche.me/e/20/f405)

# %% [markdown]
# ## Download Dataset

# %% [markdown]
# Dataset yang digunakan adalah dataset perusahaan yang termasuk dalam Fortune 500 pada tahun 2017

# %%
! wget https://www.dropbox.com/s/l3rgaxvdmg0m3ld/fortune500.csv -P dataset
# Out:
# --2026-05-07 19:54:34--  https://www.dropbox.com/s/l3rgaxvdmg0m3ld/fortune500.csv
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.81.18, 2620:100:6031:18::a27d:5112
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.81.18|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://www.dropbox.com/scl/fi/j7sy2rj9y2ja1ul2k74xt/fortune500.csv?rlkey=phx7nafi5hxve2wvpb9bow70e [following]
# --2026-05-07 19:54:35--  https://www.dropbox.com/scl/fi/j7sy2rj9y2ja1ul2k74xt/fortune500.csv?rlkey=phx7nafi5hxve2wvpb9bow70e
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc46022ea7ec2d0984ff0b2a4e85.dl.dropboxusercontent.com/cd/0/inline/DAAtJKpPLjDO6NUzEMhUEJQ_dZPAmsXsNd-E966sr74odHE-6AP_dxqc4meDlHnUZw_s_XOUS75y42n6K4iJyKdVQwD6z9BXVXU8tYEV0WtgRAiGKrYZA-8eDG59sihWRGE/file# [following]
# --2026-05-07 19:54:36--  https://uc46022ea7ec2d0984ff0b2a4e85.dl.dropboxusercontent.com/cd/0/inline/DAAtJKpPLjDO6NUzEMhUEJQ_dZPAmsXsNd-E966sr74odHE-6AP_dxqc4meDlHnUZw_s_XOUS75y42n6K4iJyKdVQwD6z9BXVXU8tYEV0WtgRAiGKrYZA-8eDG59sihWRGE/file
# Resolving uc46022ea7ec2d0984ff0b2a4e85.dl.dropboxusercontent.com (uc46022ea7ec2d0984ff0b2a4e85.dl.dropboxusercontent.com)... 162.125.81.15, 2620:100:6031:15::a27d:510f
# Connecting to uc46022ea7ec2d0984ff0b2a4e85.dl.dropboxusercontent.com (uc46022ea7ec2d0984ff0b2a4e85.dl.dropboxusercontent.com)|162.125.81.15|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 81501 (80K) [text/plain]
# Saving to: ‘dataset/fortune500.csv’
#
# fortune500.csv      100%[===================>]  79.59K  --.-KB/s    in 0.05s
#
# 2026-05-07 19:54:37 (1.68 MB/s) - ‘dataset/fortune500.csv’ saved [81501/81501]

# %% [markdown]
# ## Import Dataset ke dalam Tabel fortune500

# %% [markdown]
# Buka **PostgreSQL shell** melalui **terminal WSL** dengan perintah berikut

# %% [raw]
# psql -U user01 -d training

# %% [markdown]
# Untuk mengimport dataset ke dalam tabel fortune500, pada **PostgreSQL shell** jalankan perintah berikut

# %% [raw]
# \COPY fortune500 FROM '/home/[mila]/dataset/fortune500.csv'  DELIMITER ',' NULL 'NA' CSV HEADER;

# %% [markdown]
# catatan:
# **[user-name]** disesuaikan dengan username yang digunaka

# %% [markdown]
# Periksan table fortune500 melalui Jupyter notebook

# %%
# %%sql
# SELECT count(*) FROM fortune500
# Out:
#  * postgresql://mila:***@localhost:5432/training
# 1 rows affected.
# [(500,)]

# %%
# %%sql
# SELECT * FROM fortune500
# LIMIT 5
# Out:
#  * postgresql://mila:***@localhost:5432/training
# 5 rows affected.
# [(1, 'Walmart', 'Wal-Mart Stores, Inc.', 'WMT', 'http://www.walmart.com', 'Bentonville, AR', 'Retailing', 'General Merchandisers', 2300000, 485873, 0.8, Decimal('13643'), -7.2, Decimal('198825'), Decimal('77798')),
#  (2, 'Berkshire Hathaway', 'Berkshire Hathaway Inc.', 'BRKA', 'http://www.berkshirehathaway.com', 'Omaha, NE', 'Financials', 'Insurance: Property and Casualty (Stock)', 367700, 223604, 6.1, Decimal('24074'), 0.0, Decimal('620854'), Decimal('283001')),
#  (3, 'Apple', 'Apple, Inc.', 'AAPL', 'http://www.apple.com', 'Cupertino, CA', 'Technology', 'Computers, Office Equipment', 116000, 215639, -7.7, Decimal('45687'), -14.4, Decimal('321686'), Decimal('128249')),
#  (4, 'Exxon Mobil', 'Exxon Mobil Corporation', 'XOM', 'http://www.exxonmobil.com', 'Irving, TX', 'Energy', 'Petroleum Refining', 72700, 205004, -16.7, Decimal('7840'), -51.5, Decimal('330314'), Decimal('167325')),
#  (5, 'McKesson', 'McKesson Corporation', 'MCK', 'http://www.mckesson.com', 'San Francisco, CA', 'Wholesalers', 'Wholesalers: Health Care', 68000, 192487, 6.2, Decimal('2258'), 53.0, Decimal('56563'), Decimal('8924'))]

# %% [markdown]
# ## Jawab Dan Lengkapi Perintah SQL

# %% [markdown]
# Berikut beberapa tugas SQL yang perlu kamu lengkapi.
# Gunakan dataset Fortune 500 yang sudah di-load ke tabel **fortune500**.
#
# Lengkapi perintah SQL yang bertanda ___

# %% [markdown]
# ### 1. Berapa jumlah record pada tabel fortune500 ?

# %%
# %%sql
# SELECT COUNT(*)
# FROM fortune500;
# Out:
#  * postgresql://mila:***@localhost:5432/training
# 1 rows affected.
# [(500,)]

# %% [markdown]
# ### 2. Tampilkan Sector apa saja yang ada dalam Fortune500 !

# %% [markdown]
# Gunakan fungsi **distinct** dan urutkan berdasarkan abjad

# %%
# %%sql
# SELECT DISTINCT sector
# FROM fortune500
# ORDER BY sector ASC;
# Out:
#  * postgresql://mila:***@localhost:5432/training
# 21 rows affected.
# [('Aerospace & Defense',),
#  ('Apparel',),
#  ('Business Services',),
#  ('Chemicals',),
#  ('Energy',),
#  ('Engineering & Construction',),
#  ('Financials',),
#  ('Food & Drug Stores',),
#  ('Food, Beverages & Tobacco',),
#  ('Health Care',),
#  ('Hotels, Restaurants & Leisure',),
#  ('Household Products',),
#  ('Industrials',),
#  ('Materials',),
#  ('Media',),
#  ('Motor Vehicles & Parts',),
#  ('Retailing',),
#  ('Technology',),
#  ('Telecommunications',),
#  ('Transportation',),
#  ('Wholesalers',)]

# %% [markdown]
# ### 3. Tampilkan semua perusahaan yang berada di sektor teknologi

# %% [markdown]
# Output yang ditampilkan adalah **rank, title, name dan ticker**

# %%
# %%sql
# SELECT *
# FROM fortune500
# WHERE sector = 'Technology';
# Out:
#  * postgresql://mila:***@localhost:5432/training
# 43 rows affected.
# [(3, 'Apple', 'Apple, Inc.', 'AAPL', 'http://www.apple.com', 'Cupertino, CA', 'Technology', 'Computers, Office Equipment', 116000, 215639, -7.7, Decimal('45687'), -14.4, Decimal('321686'), Decimal('128249')),
#  (12, 'Amazon.com', 'Amazon.com, Inc.', 'AMZN', 'http://www.amazon.com', 'Seattle, WA', 'Technology', 'Internet Services and Retailing', 341400, 135987, 27.1, Decimal('2371'), 297.8, Decimal('83402'), Decimal('19285')),
#  (27, 'Alphabet', 'Alphabet Inc.', 'GOOGL', 'http://www.abc.xyz', 'Mountain View, CA', 'Technology', 'Internet Services and Retailing', 72053, 90272, 20.4, Decimal('19478'), 19.1, Decimal('167497'), Decimal('139036')),
#  (28, 'Microsoft', 'Microsoft Corporation', 'MSFT', 'http://www.microsoft.com', 'Redmond, WA', 'Technology', 'Computer Software', 114000, 85320, -8.8, Decimal('16798'), 37.8, Decimal('193694'), Decimal('71997')),
#  (32, 'IBM', 'International Business Machines Corporation', 'IBM', 'http://www.ibm.com', 'Armonk, NY', 'Technology', 'Information Technology Services', 414400, 79919, -3.1, Decimal('11872'), -10.0, Decimal('117470'), Decimal('18246')),
#  (41, 'Dell Technologies', 'Dell Technologies Inc.', None, 'http://www.delltechnologies.com', 'Round Rock, TX', 'Technology', 'Computers, Office Equipment', 138000, 64806, 18.1, Decimal('-1672'), None, Decimal('118206'), Decimal('13243')),
#  (47, 'Intel', 'Intel Corporation', 'INTC', 'http://www.intel.com', 'Santa Clara, CA', 'Technology', 'Semiconductors and Other Electronic Components', 106000, 59387, 7.3, Decimal('10316'), -9.7, Decimal('113327'), Decimal('66226')),
#  (59, 'Hewlett Packard Enterprise', 'Hewlett Packard Enterprise Company', 'HPE', 'http://www.hpe.com', 'Palo Alto, CA', 'Technology', 'Information Technology Services', 195000, 50123, 6.1, Decimal('3161'), None, Decimal('79679'), Decimal('31448')),
#  (60, 'Cisco Systems', 'Cisco Systems, Inc.', 'CSCO', 'http://www.cisco.com', 'San Jose, CA', 'Technology', 'Network and Other Communications Equipment', 73700, 49247, 0.2, Decimal('10739'), 19.6, Decimal('121652'), Decimal('63586')),
#  (61, 'HP', 'HP Inc.', 'HPQ', 'http://www.hp.com', 'Palo Alto, CA', 'Technology', 'Computers, Office Equipment', 49000, 48238, -53.3, Decimal('2496'), -45.2, Decimal('29010'), Decimal('-3889')),
#  (81, 'Oracle', 'Oracle Corporation', 'ORCL', 'http://www.oracle.com', 'Redwood City, CA', 'Technology', 'Computer Software', 136000, 37047, -3.1, Decimal('8901'), -10.4, Decimal('112180'), Decimal('47289')),
#  (98, 'Facebook', 'Facebook, Inc.', 'FB', 'http://www.facebook.com', 'Menlo Park, CA', 'Technology', 'Internet Services and Retailing', 17048, 27638, 54.2, Decimal('10217'), 177.0, Decimal('64961'), Decimal('59194')),
#  (119, 'Qualcomm', 'Qualcomm Incorporated', 'QCOM', 'http://www.qualcomm.com', 'San Diego, CA', 'Technology', 'Semiconductors and Other Electronic Components', 30500, 23554, -6.8, Decimal('5705'), 8.2, Decimal('52359'), Decimal('31778')),
#  (144, 'Danaher', 'Danaher Corporation', 'DHR', 'http://www.danaher.com', 'Washington, DC', 'Technology', 'Scientific, Photographic and Control Equipment', 62000, 19912, -4.8, Decimal('2553.7'), -23.9, Decimal('45295'), Decimal('23003')),
#  (152, 'Jabil Circuit', 'Jabil Circuit, Inc.', 'JBL', 'http://www.jabil.com', 'St. Petersburg, FL', 'Technology', 'Semiconductors and Other Electronic Components', 138000, 18353, 2.5, Decimal('254.1'), -10.5, Decimal('10323'), Decimal('2438')),
#  (154, 'Thermo Fisher Scientific', 'Thermo Fisher Scientific Inc.', 'TMO', 'http://www.thermofisher.com', 'Waltham, MA', 'Technology', 'Scientific, Photographic and Control Equipment', 54800, 18274, 7.7, Decimal('2021.8'), 2.3, Decimal('45908'), Decimal('21539')),
#  (162, 'Xerox', 'Xerox Corporation', 'XRX', 'http://www.xerox.com', 'Norwalk, CT', 'Technology', 'Computer Peripherals', 133600, 17126, -8.2, Decimal('-477'), -200.6, Decimal('18145'), Decimal('4803')),
#  (199, 'CDW', 'CDW Corporation', 'CDW', 'http://www.cdw.com', 'Lincolnshire, IL', 'Technology', 'Information Technology Services', 8516, 13982, 7.6, Decimal('424.4'), 5.3, Decimal('6948'), Decimal('1046')),
#  (205, 'Cognizant Technology Solutions', 'Cognizant Technology Solutions Corporation', 'CTSH', 'http://www.cognizant.com', 'Teaneck, NJ', 'Technology', 'Information Technology Services', 260200, 13487, 8.6, Decimal('1553'), -4.3, Decimal('14262'), Decimal('10728')),
#  (206, 'Texas Instruments', 'Texas Instruments Incorporated', 'TXN', 'http://www.ti.com', 'Dallas, TX', 'Technology', 'Semiconductors and Other Electronic Components', 29865, 13370, 2.8, Decimal('3595'), 20.4, Decimal('16431'), Decimal('10473')),
#  (217, 'Western Digital', 'Western Digital Corporation', 'WDC', 'http://www.westerndigital.com', 'Irvine, CA', 'Technology', 'Computer Peripherals', 72878, 12994, -10.8, Decimal('242'), -83.5, Decimal('32862'), Decimal('11145')),
#  (226, 'Micron Technology', 'Micron Technology, Inc.', 'MU', 'http://www.micron.com', 'Boise, ID', 'Technology', 'Semiconductors and Other Electronic Components', 31400, 12399, -23.4, Decimal('-276'), -109.5, Decimal('27540'), Decimal('12080')),
#  (265, 'Applied Materials', 'Applied Materials, Inc.', 'AMAT', 'http://www.appliedmaterials.com', 'Santa Clara, CA', 'Technology', 'Semiconductors and Other Electronic Components', 16150, 10825, 12.1, Decimal('1721'), 25.0, Decimal('14588'), Decimal('7217')),
#  (268, 'Priceline Group', 'The Priceline Group Inc.', 'PCLN', 'http://www.pricelinegroup.com', 'Norwalk, CT', 'Technology', 'Internet Services and Retailing', 18500, 10743, 16.5, Decimal('2135'), -16.3, Decimal('19839'), Decimal('9820')),
#  (310, 'eBay', 'eBay Inc.', 'EBAY', 'http://www.ebay.com', 'San Jose, CA', 'Technology', 'Internet Services and Retailing', 12600, 8979, -5.4, Decimal('7266'), 321.2, Decimal('23847'), Decimal('10539')),
#  (314, 'Netflix', 'Netflix, Inc.', 'NFLX', 'http://www.netflix.com', 'Los Gatos, CA', 'Technology', 'Internet Services and Retailing', 3850, 8831, 30.3, Decimal('186.7'), 52.2, Decimal('13587'), Decimal('2680')),
#  (317, 'Expedia', 'Expedia, Inc.', 'EXPE', 'http://www.expediainc.com', 'Bellevue, WA', 'Technology', 'Internet Services and Retailing', 20075, 8774, 31.5, Decimal('281.8'), -63.1, Decimal('15778'), Decimal('4132')),
#  (326, 'salesforce.com', 'salesforce.com, inc.', 'CRM', 'http://www.salesforce.com', 'San Francisco, CA', 'Technology', 'Computer Software', 25000, 8392, 25.9, Decimal('179.6'), None, Decimal('17585'), Decimal('7500')),
#  (363, 'Harris', 'Harris Corporation', 'HRS', 'http://www.harris.com', 'Melbourne, FL', 'Technology', 'Network and Other Communications Equipment', 21000, 7527, 48.1, Decimal('324'), -3.0, Decimal('11996'), Decimal('3056')),
#  (379, 'Computer Sciences', 'Computer Sciences Corporation', None, 'http://www.dxc.technology', 'Tysons, VA', 'Technology', 'Information Technology Services', 59000, 7106, -41.7, Decimal('251'), 12450.0, Decimal('7736'), Decimal('2025')),
#  (381, 'Leidos Holdings', 'Leidos Holdings, Inc.', 'LDOS', 'http://www.leidos.com', 'Reston, VA', 'Technology', 'Information Technology Services', 32000, 7043, 38.5, Decimal('244'), -3.9, Decimal('9132'), Decimal('3135')),
#  (387, 'Nvidia', 'NVIDIA Corporation', 'NVDA', 'http://www.nvidia.com', 'Santa Clara, CA', 'Technology', 'Semiconductors and Other Electronic Components', 10299, 6910, 37.9, Decimal('1666'), 171.3, Decimal('9841'), Decimal('5762')),
#  (406, 'Activision Blizzard', 'Activision Blizzard, Inc.', 'ATVI', 'http://www.activisionblizzard.com', 'Santa Monica, CA', 'Technology', 'Computer Software', 9500, 6608, 41.7, Decimal('966'), 8.3, Decimal('17452'), Decimal('9119')),
#  (409, 'NCR', 'NCR Corporation', 'NCR', 'http://www.ncr.com', 'Duluth, GA', 'Technology', 'Computers, Office Equipment', 33500, 6543, 2.7, Decimal('270'), None, Decimal('7673'), Decimal('1542')),
#  (414, 'Sanmina', 'Sanmina Corporation', 'SANM', 'http://www.sanmina.com', 'San Jose, CA', 'Technology', 'Semiconductors and Other Electronic Components', 40178, 6481, 1.7, Decimal('187.8'), -50.2, Decimal('3625'), Decimal('1610')),
#  (424, 'Amphenol', 'Amphenol Corporation', 'APH', 'http://www.amphenol.com', 'Wallingford, CT', 'Technology', 'Network and Other Communications Equipment', 62000, 6286, 12.9, Decimal('822.9'), 7.8, Decimal('8499'), Decimal('3675')),
#  (433, 'Motorola Solutions', 'Motorola Solutions, Inc.', 'MSI', 'http://www.motorolasolutions.com', 'Chicago, IL', 'Technology', 'Network and Other Communications Equipment', 14000, 6038, 6.0, Decimal('560'), -8.2, Decimal('8463'), Decimal('-964')),
#  (440, 'Lam Research', 'Lam Research Corporation', 'LRCX', 'http://www.lamresearch.com', 'Fremont, CA', 'Technology', 'Semiconductors and Other Electronic Components', 7500, 5886, 11.9, Decimal('914'), 39.4, Decimal('12272'), Decimal('5895')),
#  (443, 'Adobe Systems', 'Adobe Systems Incorporated', 'ADBE', 'http://www.adobe.com', 'San Jose, CA', 'Technology', 'Computer Software', 15706, 5854, 22.1, Decimal('1168.8'), 85.7, Decimal('12707'), Decimal('7425')),
#  (465, 'Symantec', 'Symantec Corporation', 'SYMC', 'http://www.symantec.com', 'Mountain View, CA', 'Technology', 'Computer Software', 11000, 5568, -14.4, Decimal('2488'), 183.4, Decimal('11767'), Decimal('3676')),
#  (468, 'NetApp', 'NetApp, Inc.', 'NTAP', 'http://www.netapp.com', 'Sunnyvale, CA', 'Technology', 'Computer Peripherals', 12030, 5546, -9.4, Decimal('229'), -59.1, Decimal('10037'), Decimal('2881')),
#  (481, 'Booz Allen Hamilton Holding', 'Booz Allen Hamilton Holding Corp.', 'BAH', 'http://www.boozallen.com', 'McLean, VA', 'Technology', 'Information Technology Services', 22600, 5406, 2.5, Decimal('294.1'), 26.5, Decimal('3010'), Decimal('409')),
#  (498, 'Yahoo', 'Yahoo! Inc.', 'YHOO', 'http://www.yahoo.com', 'Sunnyvale, CA', 'Technology', 'Internet Services and Retailing', 8500, 5169, 4.0, Decimal('-214.3'), None, Decimal('48083'), Decimal('31049'))]

# %% [markdown]
# ### 4. Tampilkan semua perusahaan yang tidak memiliki kode saham (ticker) !

# %% [markdown]
# Output yang ditampilkan adalah **rank, title, name dan ticker**

# %% [markdown]
# ***Petunjuk:***
#
# Gunakan filter **ticker is null**

# %%
# %%sql
# SELECT *
# FROM fortune500
# WHERE ticker IS NULL;
# Out:
#  * postgresql://mila:***@localhost:5432/training
# The history saving thread hit an unexpected error (OperationalError('attempt to write a readonly database')).History will not be written to the database.
# 32 rows affected.
# [(33, 'State Farm Insurance Cos.', 'State Farm Insurance Cos.', None, 'http://www.statefarm.com', 'Bloomington, IL', 'Financials', 'Insurance: Property and Casualty (Mutual)', 68234, 76132, 0.6, Decimal('350.3'), -94.4, Decimal('256030'), Decimal('87592')),
#  (41, 'Dell Technologies', 'Dell Technologies Inc.', None, 'http://www.delltechnologies.com', 'Round Rock, TX', 'Technology', 'Computers, Office Equipment', 138000, 64806, 18.1, Decimal('-1672'), None, Decimal('118206'), Decimal('13243')),
#  (49, 'Albertsons Cos.', 'Albertsons Companies, Inc.', None, 'http://www.albertsons.com', 'Boise, ID', 'Food & Drug Stores', 'Food and Drug Stores', 274000, 58734, 115.9, Decimal('-502.2'), None, Decimal('23770'), Decimal('1613')),
#  (65, 'New York Life Insurance', 'New York Life Insurance Company', None, 'http://www.newyorklife.com', 'New York, NY', 'Financials', 'Insurance: Life, Health (Mutual)', 11320, 40787, -11.1, Decimal('1088.1'), 324.1, Decimal('287196'), Decimal('20108')),
#  (68, 'Nationwide', 'Nationwide Mutual Insurance Co.', None, 'http://www.nationwide.com', 'Columbus, OH', 'Financials', 'Insurance: Property and Casualty (Mutual)', 34320, 40074, -0.4, Decimal('334.3'), -42.4, Decimal('197790'), Decimal('15537')),
#  (75, 'Liberty Mutual Insurance Group', 'Liberty Mutual Holding Company Inc.', None, 'http://www.libertymutual.com', 'Boston, MA', 'Financials', 'Insurance: Property and Casualty (Stock)', 50000, 38308, -2.9, Decimal('1006'), 95.7, Decimal('125592'), Decimal('20366')),
#  (77, 'Massachusetts Mutual Life Insurance', 'Massachusetts Mutual Life Insurance Company', None, 'http://www.massmutual.com', 'Springfield, MA', 'Financials', 'Insurance: Life, Health (Mutual)', 11737, 37788, -1.2, Decimal('1273.5'), -10.6, Decimal('271040'), Decimal('15424')),
#  (80, 'TIAA', 'Teachers Insurance and Annuity Association', None, 'http://www.tiaa.org', 'New York, NY', 'Financials', 'Insurance: Life, Health (Mutual)', 12997, 37105, 5.5, Decimal('1492.3'), 22.9, Decimal('523194'), Decimal('35583')),
#  (85, 'Publix Super Markets', 'Publix Super Markets, Inc.', None, 'http://www.publix.com', 'Lakeland, FL', 'Food & Drug Stores', 'Food and Drug Stores', 191000, 34274, 5.1, Decimal('2025.7'), 3.1, Decimal('17464'), Decimal('13473')),
#  (93, 'CHS', 'CHS Inc.', None, 'http://www.chsinc.com', 'Inver Grove Heights, MN', 'Food, Beverages & Tobacco', 'Food Production', 12157, 30347, -12.2, Decimal('424.2'), -45.7, Decimal('17318'), Decimal('7852')),
#  (97, 'Northwestern Mutual', 'Northwestern Mutual Life Insurance Company, Inc.', None, 'http://www.northwesternmutual.com', 'Milwaukee, WI', 'Financials', 'Insurance: Life, Health (Mutual)', 5646, 28799, 2.4, Decimal('818'), 0.4, Decimal('250441'), Decimal('20226')),
#  (102, 'USAA', 'United Services Automobile Association', None, 'http://www.usaa.com', 'San Antonio, TX', 'Financials', 'Insurance: Property and Casualty (Stock)', 29943, 27131, 11.4, Decimal('1779.1'), -21.7, Decimal('147290'), Decimal('28840')),
#  (209, 'Land O’Lakes', "Land O'Lakes, Inc.", None, 'http://www.landolakesinc.com', 'Arden Hills, MN', 'Food, Beverages & Tobacco', 'Food Consumer Products', 10000, 13233, 0.6, Decimal('244.9'), -20.4, Decimal('8305'), Decimal('1904')),
#  (218, 'Guardian Life Ins. Co. of America', 'Guardian Life Ins. Co. of America', None, 'http://www.guardianlife.com', 'New York, NY', 'Financials', 'Insurance: Life, Health (Mutual)', 8876, 12919, 2.3, Decimal('263.9'), -35.7, Decimal('70339'), Decimal('6172.5')),
#  (222, 'Farmers Insurance Exchange', 'Farmers Insurance Exchange', None, 'http://www.farmers.com', 'Woodland Hills, CA', 'Financials', 'Insurance: Property and Casualty (Mutual)', 13309, 12513, -0.9, Decimal('-147.9'), None, Decimal('16057'), Decimal('4219')),
#  (244, 'Toys “R” Us', 'Toys "R" Us, Inc.', None, 'http://www.toysrusinc.com', 'Wayne, NJ', 'Retailing', 'Specialty Retailers: Other', 64000, 11540, -2.2, Decimal('-36'), None, Decimal('6908'), Decimal('-1292')),
#  (302, 'Pacific Life', 'Pacific Life', None, 'http://www.pacificlife.com', 'Newport Beach, CA', 'Financials', 'Insurance: Life, Health (Stock)', 3628, 9169, 6.1, Decimal('824'), 24.7, Decimal('143298'), Decimal('11022')),
#  (315, 'American Family Insurance Group', 'American Family Insurance Group', None, 'http://www.amfam.com', 'Madison, WI', 'Financials', 'Insurance: Property and Casualty (Stock)', 10471, 8829, 6.6, Decimal('325.6'), -53.1, Decimal('22662'), Decimal('7760')),
#  (316, 'Thrivent Financial for Lutherans', 'Thrivent Financial for Lutherans', None, 'http://www.thrivent.com', 'Minneapolis, MN', 'Financials', 'Insurance: Life, Health (Mutual)', 3282, 8777, -0.1, Decimal('587.8'), -23.6, Decimal('88561'), Decimal('7726')),
#  (324, 'Peter Kiewit Sons’', "Peter Kiewit Sons', Inc.", None, 'http://www.kiewit.com', 'Omaha, NE', 'Engineering & Construction', 'Engineering, Construction', 20000, 8573, -4.7, Decimal('396'), 57.8, Decimal('6179'), Decimal('3268')),
#  (342, 'Mutual of Omaha Insurance', 'Mutual of Omaha Insurance Company', None, 'http://www.mutualofomaha.com', 'Omaha, NE', 'Financials', 'Insurance: Life, Health (Stock)', 5732, 7899, 9.2, Decimal('356.6'), 7.1, Decimal('38465'), Decimal('5618')),
#  (349, 'Western Refining', 'Western Refining, Inc.', None, 'http://www.wnr.com', 'El Paso, TX', 'Energy', 'Petroleum Refining', 7134, 7743, -20.9, Decimal('124.9'), -69.3, Decimal('5560'), Decimal('1697')),
#  (379, 'Computer Sciences', 'Computer Sciences Corporation', None, 'http://www.dxc.technology', 'Tysons, VA', 'Technology', 'Information Technology Services', 59000, 7106, -41.7, Decimal('251'), 12450.0, Decimal('7736'), Decimal('2025')),
#  (382, 'Erie Insurance Group', 'Erie Insurance Group', None, 'http://www.erieinsurance.com', 'Erie, PA', 'Financials', 'Insurance: Property and Casualty (Mutual)', 4988, 7016, 5.7, Decimal('741.9'), 10.7, Decimal('18417'), Decimal('8528')),
#  (386, 'Harman International Industries', 'Harman International Industries, Incorporated', None, 'http://www.harman.com', 'Stamford, CT', 'Industrials', 'Electronics, Electrical Equipment', 26000, 6912, 12.3, Decimal('361.7'), 5.6, Decimal('6054'), Decimal('2453')),
#  (398, 'Auto-Owners Insurance', 'Auto-Owners Insurance Group', None, 'http://www.auto-owners.com', 'Lansing, MI', 'Financials', None, 4737, 6775, 4.0, Decimal('706.3'), -13.4, Decimal('21571'), Decimal('9690')),
#  (403, 'JetBlue Airways', 'JetBlue Airways Corporation', None, 'http://www.jetblue.com', 'Long Island City, NY', 'Transportation', 'Airlines', 15986, 6632, 3.4, Decimal('759'), 12.1, Decimal('9487'), Decimal('4013')),
#  (420, 'Graybar Electric', 'Graybar Electric Company, Inc.', None, 'http://www.graybar.com', 'St. Louis, MO', 'Wholesalers', 'Wholesalers: Diversified', 8500, 6385, 4.5, Decimal('93.1'), 2.2, Decimal('2099'), Decimal('728')),
#  (434, 'St. Jude Medical', 'St. Jude Medical, Inc.', None, 'http://www.abbott.com', 'St. Paul, MN', 'Health Care', 'Medical Products and Equipment', 18000, 6004, 8.4, Decimal('734'), -16.6, Decimal('12578'), Decimal('4578')),
#  (483, 'Western & Southern Financial Group', 'Western & Southern Mutual Holding Company', None, 'http://www.westernsouthern.com', 'Cincinnati, OH', 'Financials', 'Insurance: Life, Health (Mutual)', 2178, 5398, 0.8, Decimal('241.2'), -47.2, Decimal('43831'), Decimal('5104')),
#  (489, 'Airgas', 'Airgas, Inc.', None, 'http://www.airgas.com', 'Radnor, PA', 'Wholesalers', 'Wholesalers: Diversified', 17000, 5314, 0.2, Decimal('337.5'), -8.3, Decimal('6135'), Decimal('2045')),
#  (494, 'CH2M Hill', 'CH2M HILL Companies, Ltd.', None, 'http://www.ch2m.com', 'Englewood, CO', 'Engineering & Construction', 'Engineering, Construction', 20000, 5236, -2.3, Decimal('15'), -81.3, Decimal('2671'), Decimal('547'))]

# %% [markdown]
# ### 5. Tampilkan semua perusahaan yang memiliki panjang kode saham hanya 2 karakter

# %% [markdown]
# Output yang ditampilkan adalah **rank, title, name, ticker dan sector**

# %%
# %%sql
# SELECT *
# FROM fortune500
# WHERE LENGTH(ticker) = 2;
# Out:
#  * postgresql://mila:***@localhost:5432/training
# 49 rows affected.
# [(8, 'General Motors', 'General Motors Company', 'GM', 'http://www.gm.com', 'Detroit, MI', 'Motor Vehicles & Parts', 'Motor Vehicles and Parts', 225000, 166380, 9.2, Decimal('9427'), -2.7, Decimal('221690'), Decimal('43836')),
#  (13, 'General Electric', 'General Electric Company', 'GE', 'http://www.ge.com', 'Boston, MA', 'Industrials', 'Industrial Machinery', 295000, 126661, -9.8, Decimal('8831'), None, Decimal('365183'), Decimal('75828')),
#  (14, 'Verizon', 'Verizon Communications Inc.', 'VZ', 'http://www.verizon.com', 'New York, NY', 'Telecommunications', 'Telecommunications', 160900, 125980, -4.3, Decimal('13127'), -26.6, Decimal('244180'), Decimal('22524')),
#  (18, 'Kroger', 'The Kroger Company', 'KR', 'http://www.thekrogerco.com', 'Cincinnati, OH', 'Food & Drug Stores', 'Food and Drug Stores', 443000, 115337, 5.0, Decimal('1975'), -3.1, Decimal('36505'), Decimal('6698')),
#  (23, 'Home Depot', 'The Home Depot, Inc.', 'HD', 'http://www.homedepot.com', 'Atlanta, GA', 'Retailing', 'Specialty Retailers: Other', 406000, 94595, 6.9, Decimal('7957'), 13.5, Decimal('42966'), Decimal('4333')),
#  (24, 'Boeing', 'The Boeing Company', 'BA', 'http://www.boeing.com', 'Chicago, IL', 'Aerospace & Defense', 'Aerospace and Defense', 150540, 94571, -1.6, Decimal('4895'), -5.4, Decimal('89997'), Decimal('817')),
#  (36, 'Procter & Gamble', 'The Procter & Gamble Company', 'PG', 'http://www.pg.com', 'Cincinnati, OH', 'Household Products', 'Household and Personal Products', 105000, 71726, -8.9, Decimal('10508'), 49.3, Decimal('127136'), Decimal('57341')),
#  (64, 'Coca-Cola', 'The Coca-Cola Company', 'KO', 'http://www.coca-colacompany.com', 'Atlanta, GA', 'Food, Beverages & Tobacco', 'Beverages', 100300, 41863, -5.5, Decimal('6527'), -11.2, Decimal('87270'), Decimal('23062')),
#  (70, 'Cigna', 'CIGNA Corporation', 'CI', 'http://www.cigna.com', 'Bloomfield, CT', 'Health Care', 'Health Care: Insurance and Managed Care', 41000, 39668, 4.7, Decimal('1867'), -10.8, Decimal('59360'), Decimal('13723')),
#  (76, 'Morgan Stanley', 'Morgan Stanley', 'MS', 'http://www.morganstanley.com', 'New York, NY', 'Financials', 'Commercial Banks', 55311, 37949, 0.1, Decimal('5979'), -2.4, Decimal('814949'), Decimal('76050')),
#  (78, 'Goldman Sachs Group', 'The Goldman Sachs Group, Inc.', 'GS', 'http://www.gs.com', 'New York, NY', 'Financials', 'Commercial Banks', 34400, 37712, -3.8, Decimal('7398'), 21.6, Decimal('860165'), Decimal('86893')),
#  (90, 'General Dynamics', 'General Dynamics Corporation', 'GD', 'http://www.generaldynamics.com', 'Falls Church, VA', 'Aerospace & Defense', 'Aerospace and Defense', 98800, 31353, -0.4, Decimal('2955'), -0.3, Decimal('32872'), Decimal('10976')),
#  (98, 'Facebook', 'Facebook, Inc.', 'FB', 'http://www.facebook.com', 'Menlo Park, CA', 'Technology', 'Internet Services and Retailing', 17048, 27638, 54.2, Decimal('10217'), 177.0, Decimal('64961'), Decimal('59194')),
#  (104, 'Philip Morris International', 'Philip Morris International Inc.', 'PM', 'http://www.pmi.com', 'New York, NY', 'Food, Beverages & Tobacco', 'Tobacco', 79500, 26685, -0.4, Decimal('6967'), 1.4, Decimal('36851'), Decimal('-12688')),
#  (105, 'Deere', 'Deere & Company', 'DE', 'http://www.johndeere.com', 'Moline, IL', 'Industrials', 'Construction and Farm Machinery', 56767, 26644, -7.7, Decimal('1523.9'), -21.4, Decimal('57981'), Decimal('6520')),
#  (113, 'DuPont', 'E.I. du Pont de Nemours and Company', 'DD', 'http://www.dupont.com', 'Wilmington, DE', 'Chemicals', 'Chemicals', 46000, None, -12.0, Decimal('2513'), 28.7, Decimal('39964'), Decimal('9998')),
#  (128, 'Dollar General', 'Dollar General Corporation', 'DG', 'http://www.dollargeneral.com', 'Goodlettsville, TN', 'Retailing', 'Specialty Retailers: Other', 121000, 21987, 7.9, Decimal('1251.1'), 7.4, Decimal('11672'), Decimal('5406')),
#  (129, 'AutoNation', 'AutoNation, Inc.', 'AN', 'http://www.autonation.com', 'Fort Lauderdale, FL', 'Retailing', 'Automotive Retailing, Services', 26000, 21609, 3.6, Decimal('430.5'), -2.7, Decimal('10060'), Decimal('2310')),
#  (133, 'International Paper', 'International Paper Company', 'IP', 'http://www.internationalpaper.com', 'Memphis, TN', 'Materials', 'Packaging, Containers', 55000, 21079, -5.8, Decimal('904'), -3.6, Decimal('33345'), Decimal('4341')),
#  (145, 'Southern', 'The Southern Company', 'SO', 'http://www.southerncompany.com', 'Atlanta, GA', 'Energy', 'Utilities: Gas and Electric', 32015, 19896, 13.8, Decimal('2448'), 3.4, Decimal('109697'), Decimal('24758')),
#  (148, 'Altria Group', 'Altria Group, Inc.', 'MO', 'http://www.altria.com', 'Richmond, VA', 'Food, Beverages & Tobacco', 'Tobacco', 8300, 19337, 2.6, Decimal('14239'), 171.7, Decimal('45932'), Decimal('12770')),
#  (177, 'Bank of New York Mellon', 'The Bank of New York Mellon Corporation', 'BK', 'http://www.bnymellon.com', 'New York, NY', 'Financials', 'Commercial Banks', 52000, 15683, 1.0, Decimal('3547'), 12.3, Decimal('333469'), Decimal('38811')),
#  (182, 'Colgate-Palmolive', 'Colgate-Palmolive Company', 'CL', 'http://www.colgatepalmolive.com', 'New York, NY', 'Household Products', 'Household and Personal Products', 36700, 15195, -5.2, Decimal('2441'), 76.4, Decimal('12123'), Decimal('-243')),
#  (184, 'Goodyear Tire & Rubber', 'The Goodyear Tire & Rubber Company', 'GT', 'http://www.goodyear.com', 'Akron, OH', 'Motor Vehicles & Parts', 'Motor Vehicles and Parts', 66000, 15158, -7.8, Decimal('1264'), 311.7, Decimal('16511'), Decimal('4507')),
#  (196, 'FirstEnergy', 'FirstEnergy Corp.', 'FE', 'http://www.firstenergycorp.com', 'Akron, OH', 'Energy', 'Utilities: Gas and Electric', 15707, 14156, -3.1, Decimal('-6177'), -1168.7, Decimal('43148'), Decimal('6241')),
#  (201, 'Waste Management', 'Waste Management, Inc.', 'WM', 'http://www.wm.com', 'Houston, TX', 'Business Services', 'Waste Management', 41200, 13609, 5.0, Decimal('1182'), 57.0, Decimal('20859'), Decimal('5297')),
#  (220, 'L Brands', 'L Brands, Inc.', 'LB', 'http://www.lb.com', 'Columbus, OH', 'Retailing', 'Specialty Retailers: Apparel', 59100, 12574, 3.5, Decimal('1158.1'), -7.6, Decimal('8170'), Decimal('-729')),
#  (226, 'Micron Technology', 'Micron Technology, Inc.', 'MU', 'http://www.micron.com', 'Boise, ID', 'Technology', 'Semiconductors and Other Electronic Components', 31400, 12399, -23.4, Decimal('-276'), -109.5, Decimal('27540'), Decimal('12080')),
#  (234, 'Consolidated Edison', 'Consolidated Edison, Inc.', 'ED', 'http://www.conedison.com', 'New York, NY', 'Energy', 'Utilities: Gas and Electric', 14960, 12075, -3.8, Decimal('1245'), 4.4, Decimal('48255'), Decimal('14298')),
#  (251, 'Parker-Hannifin', 'Parker-Hannifin Corporation', 'PH', 'http://www.parker.com', 'Cleveland, OH', 'Industrials', 'Industrial Machinery', 48950, 11361, -10.6, Decimal('806.8'), -20.3, Decimal('12057'), Decimal('4575')),
#  (253, 'Estee Lauder', 'The Estee Lauder Companies Inc.', 'EL', 'http://www.elcompanies.com', 'New York, NY', 'Household Products', 'Household and Personal Products', 46000, 11262, 4.5, Decimal('1114.6'), 2.4, Decimal('9223'), Decimal('3572')),
#  (267, 'Mastercard', 'Mastercard Incorporated', 'MA', 'http://www.mastercard.com', 'Purchase, NY', 'Business Services', 'Financial Data Services', 11900, 10776, 11.5, Decimal('4059'), 6.6, Decimal('18675'), Decimal('5656')),
#  (275, 'Praxair', 'Praxair, Inc.', 'PX', 'http://www.praxair.com', 'Danbury, CT', 'Chemicals', 'Chemicals', 26498, 10534, -2.2, Decimal('1500'), -3.0, Decimal('19332'), Decimal('5021')),
#  (290, 'Laboratory Corp. of America', 'Laboratory Corporation of America Holdings', 'LH', 'http://www.labcorp.com', 'Burlington, NC', 'Health Care', 'Health Care: Pharmacy and Other Services', 52000, 9642, 11.1, Decimal('732.1'), 67.6, Decimal('14247'), Decimal('5506')),
#  (300, 'Alcoa', 'Alcoa Corporation', 'AA', 'http://www.alcoa.com', 'New York, NY', 'Materials', 'Metals', 14000, 9318, 3.0, Decimal('-400'), None, Decimal('16741'), Decimal('5654')),
#  (320, 'Reliance Steel & Aluminum', 'Reliance Steel & Aluminum Co.', 'RS', 'http://www.rsac.com', 'Los Angeles, CA', 'Materials', 'Metals', 14500, 8613, -7.9, Decimal('304.3'), -2.3, Decimal('7411'), Decimal('4149')),
#  (341, 'Weyerhaeuser', 'Weyerhaeuser Company', 'WY', 'http://www.weyerhaeuser.com', 'Seattle, WA', 'Materials', 'Forest and Paper Products', 10400, 7902, 11.6, Decimal('1027'), 103.0, Decimal('19243'), Decimal('9180')),
#  (348, 'Foot Locker', 'Foot Locker, Inc.', 'FL', 'http://www.footlocker-inc.com', 'New York, NY', 'Retailing', 'Specialty Retailers: Apparel', 32965, 7766, 4.8, Decimal('664'), 22.7, Decimal('3840'), Decimal('2710')),
#  (351, 'Dean Foods', 'Dean Foods Company', 'DF', 'http://www.deanfoods.com', 'Dallas, TX', 'Food, Beverages & Tobacco', 'Food Consumer Products', 17000, 7710, -5.1, Decimal('119.9'), None, Decimal('2606'), Decimal('611')),
#  (358, 'Eversource Energy', 'Eversource Energy', 'ES', 'http://www.eversource.com', 'Springfield, MA', 'Energy', 'Utilities: Gas and Electric', 7762, 7639, -4.0, Decimal('942.3'), 7.3, Decimal('32053'), Decimal('10712')),
#  (371, 'Ralph Lauren', 'Ralph Lauren Corporation', 'RL', 'http://www.ralphlauren.com', 'New York, NY', 'Apparel', 'Apparel', 20500, 7405, -2.8, Decimal('396'), -43.6, Decimal('6213'), Decimal('3744')),
#  (401, 'Owens-Illinois', 'Owens-Illinois, Inc.', 'OI', 'http://www.o-i.com', 'Perrysburg, OH', 'Materials', 'Packaging, Containers', 27000, 6702, 8.9, Decimal('209'), 54.8, Decimal('9135'), Decimal('254')),
#  (436, 'Regions Financial', 'Regions Financial Corporation', 'RF', 'http://www.regions.com', 'Birmingham, AL', 'Financials', 'Commercial Banks', 22166, 5967, 5.2, Decimal('1163'), 9.5, Decimal('125968'), Decimal('16664')),
#  (458, 'Owens Corning', 'Owens Corning', 'OC', 'http://www.owenscorning.com', 'Toledo, OH', 'Materials', 'Building Materials, Glass', 16000, 5677, 6.1, Decimal('393'), 19.1, Decimal('7741'), Decimal('3849')),
#  (470, 'TravelCenters of America', 'TravelCenters of America LLC', 'TA', 'http://www.ta-petrol.com', 'Westlake, OH', 'Retailing', 'Specialty Retailers: Other', 20259, 5511, -5.8, Decimal('-2'), -107.3, Decimal('1660'), Decimal('552')),
#  (478, 'Western Union', 'The Western Union Company', 'WU', 'http://www.westernunion.com', 'Englewood, CO', 'Business Services', 'Financial Data Services', 10700, 5423, -1.1, Decimal('253.2'), -69.8, Decimal('9420'), Decimal('902')),
#  (480, 'Delek US Holdings', 'Delek US Holdings, Inc.', 'DK', 'http://www.delekus.com', 'Brentwood, TN', 'Energy', 'Petroleum Refining', 1326, 5414, -6.0, Decimal('-153.7'), -892.3, Decimal('2985'), Decimal('992')),
#  (482, 'Chemours', 'The Chemours Company', 'CC', 'http://www.chemours.com', 'Wilmington, DE', 'Chemicals', 'Chemicals', 7000, 5400, 2.5, Decimal('7'), None, Decimal('6060'), Decimal('100')),
#  (484, 'Celanese', 'Celanese Corporation', 'CE', 'http://www.celanese.com', 'Irving, TX', 'Chemicals', 'Chemicals', 7293, 5389, -5.0, Decimal('900'), 196.1, Decimal('8357'), Decimal('2588'))]

# %% [markdown]
# Ada berapa perusahaan yang memiliki panjang kode sahamnya 2?

# %%
# %%sql
# SELECT COUNT(*)
# FROM fortune500
# WHERE ticker IS NOT NULL AND LENGTH(ticker) = 2;
# Out:
#  * postgresql://mila:***@localhost:5432/training
# 1 rows affected.
# [(49,)]

# %% [markdown]
# ### 6. Berapa revenue Apple, Amazon, Facebook, dan Google?

# %% [markdown]
# Output yang ditampilkan adalah **rank, title, revenues, jumlah karyawan (employees)**

# %% [markdown]
# _**Petunjuk:**_
#
# Kode saham (ticker) untuk Apple: AAPL, Amazon: AMZN, Facebook: FB, Google: GOOGL

# %%
# %%sql
# SELECT name, revenues
# FROM fortune500
# WHERE name IN ('Apple, Inc.', 'Amazon.com, Inc.', 'Facebook, Inc.', 'Alphabet Inc.');
# Out:
#  * postgresql://mila:***@localhost:5432/training
# 4 rows affected.
# [('Apple, Inc.', 215639),
#  ('Amazon.com, Inc.', 135987),
#  ('Alphabet Inc.', 90272),
#  ('Facebook, Inc.', 27638)]

# %% [markdown]
# ### 7. Tampilkan 10 perusahaan yang memiliki pendapatan (revenues) terkecil

# %% [markdown]
# Output yang ditampilkan adalah **rank, title, revenues**

# %% [markdown]
# Catatan: Jumlah revenue yang ditampilkan dalam **juta dolar**

# %%
# %%sql
# SELECT name, revenues
# FROM fortune500
# ORDER BY revenues ASC
# LIMIT 10;
# Out:
#  * postgresql://mila:***@localhost:5432/training
# 10 rows affected.
# [('ABM Industries Incorporated', 5145),
#  ('Vistra Energy Corp.', 5164),
#  ('Yahoo! Inc.', 5169),
#  ('Toll Brothers, Inc.', 5170),
#  ('The Michaels Companies, Inc.', 5197),
#  ('Big Lots, Inc.', 5200),
#  ('CH2M HILL Companies, Ltd.', 5236),
#  ('Robert Half International Inc.', 5250),
#  ('Rockwell Collins, Inc.', 5259),
#  ('Liberty Media Corporation', 5276)]

# %% [markdown]
# ### 8. Tampilkan perusahaan yang memiliki pendapatan (revenues) diatas 150.000 juta dolar

# %% [markdown]
# Output yang ditampilkan adalah **rank, title, sector, revenues** dan urutkan berdasarkan revenue yang terbesar

# %% [markdown]
# Catatan: Jumlah pendapatan (revenues) yang ada dalam tabel fortune500 sudah dalam satuan juta dolar

# %%
# %%sql
# SELECT rank, title, sector, revenues
# FROM fortune500
# WHERE revenues > 150000
# ORDER BY revenues DESC;
# Out:
#  * postgresql://mila:***@localhost:5432/training
# 10 rows affected.
# [(1, 'Walmart', 'Retailing', 485873),
#  (2, 'Berkshire Hathaway', 'Financials', 223604),
#  (3, 'Apple', 'Technology', 215639),
#  (4, 'Exxon Mobil', 'Energy', 205004),
#  (5, 'McKesson', 'Wholesalers', 192487),
#  (6, 'UnitedHealth Group', 'Health Care', 184840),
#  (7, 'CVS Health', 'Health Care', 177526),
#  (8, 'General Motors', 'Motor Vehicles & Parts', 166380),
#  (9, 'AT&T', 'Telecommunications', 163786),
#  (10, 'Ford Motor', 'Motor Vehicles & Parts', 151800)]

# %% [markdown]
# ### 9. Berapa jumlah perusahaan yang memiliki pendapatan diantara 100.000 dan 200.000 juta dolar ?

# %%
# %%sql
# SELECT COUNT(*)
# FROM fortune500
# WHERE revenues BETWEEN 100000 AND 200000;
# Out:
#  * postgresql://mila:***@localhost:5432/training
# 1 rows affected.
# [(18,)]

# %% [markdown]
# ### 10. Tampilkan 10 perusahaan yang mengalami penurunan keuntungan terbesar !

# %% [markdown]
# Output yang ditampilkan adalah **title, sector, revenues, profits, profits_change dan revenues_change**

# %% [markdown]
# _**Petunjuk:**_
#
# Kolom **profits_change** adalah perubahan keuntungan perusahaan dibandingkan tahun sebelumnya. Jika bernilai positif maka perusahaan tersebut memiliki keuntungan, dan jika negatif maka perusahaan tersebut mengalami penurunan keuntungan.

# %%
# %%sql
# SELECT title, sector, revenues, profits, profits_change, revenues_change
# FROM fortune500
# WHERE profits_change < 0
# ORDER BY profits_change ASC
# LIMIT 10;
# Out:
#  * postgresql://mila:***@localhost:5432/training
# 10 rows affected.
# [('Windstream Holdings', 'Telecommunications', 5387, Decimal('-383.5'), -1499.6, -6.6),
#  ('Community Health Systems', 'Health Care', 21374, Decimal('-1721'), -1189.2, -5.8),
#  ('FirstEnergy', 'Energy', 14156, Decimal('-6177'), -1168.7, -3.1),
#  ('Delek US Holdings', 'Energy', 5414, Decimal('-153.7'), -892.3, -6.0),
#  ('NGL Energy Partners', 'Energy', 11742, Decimal('-198.9'), -633.2, -30.1),
#  ('Global Partners', 'Wholesalers', 8240, Decimal('-199.4'), -557.8, -20.1),
#  ('Univar', 'Wholesalers', 8074, Decimal('-68.4'), -514.5, -10.1),
#  ('Staples', 'Retailing', 20217, Decimal('-1497'), -494.8, -4.0),
#  ('AES', 'Energy', 14287, Decimal('-1130'), -469.3, -4.5),
#  ('R.R. Donnelley & Sons', 'Media', 6896, Decimal('-495.9'), -428.2, -38.7)]

# %% [markdown]
# ### 11. Tampilkan 10 perusahaan yang sedang naik daun (memiliki pertumbuhan pendapatan tertinggi) !

# %% [markdown]
# Output yang ditampilkan adalah **title, sector, revenues, profits, profits_change dan revenues_change**

# %% [markdown]
# _**Petunjuk:**_
#
# Kolom **revenues_change** adalah perubahan keuntungan perusahaan dibandingkan tahun sebelumnya dalam persentase. Jika bernilai positif maka perusahaan tersebut memiliki keuntungan, dan jika negatif maka perusahaan tersebut mengalami penurunan keuntungan.

# %%
# %%sql
# SELECT title, sector, revenues, profits, profits_change, revenues_change
# FROM fortune500
# WHERE revenues_change IS NOT NULL
# ORDER BY revenues_change DESC
# LIMIT 10;
# Out:
#  * postgresql://mila:***@localhost:5432/training
# 10 rows affected.
# [('Charter Communications', 'Telecommunications', 29003, Decimal('3522'), None, 197.3),
#  ('Newell Brands', 'Household Products', 13264, Decimal('527.8'), 50.8, 122.1),
#  ('Albertsons Cos.', 'Food & Drug Stores', 58734, Decimal('-502.2'), None, 115.9),
#  ('Olin', 'Chemicals', 5551, Decimal('-3.9'), None, 94.5),
#  ('TreeHouse Foods', 'Food, Beverages & Tobacco', 6175, Decimal('-228.6'), -298.9, 92.6),
#  ('XPO Logistics', 'Transportation', 14619, Decimal('69'), None, 91.8),
#  ('CalAtlantic Group', 'Engineering & Construction', 6477, Decimal('484.7'), 127.0, 83.0),
#  ('Centene', 'Health Care', 40721, Decimal('562'), 58.3, 78.6),
#  ('Builders FirstSource', 'Materials', 6367, Decimal('144.3'), None, 78.6),
#  ('Tesla', 'Motor Vehicles & Parts', 7000, Decimal('-674.9'), None, 73.0)]

# %% [markdown]
# ### 12. Tampilkan 10 perusahaan yang memiliki rasio profit terhadap pendapatan (Profit Margin) tertinggi

# %% [markdown]
# Output yang ditampilkan adalah **name, sector, revenues, profits dan profit_margin**

# %% [markdown]
# _**Petunjuk:**_
#
# **profit_margin** adalah rasio profit terhadap pendapatan, yang dihitung dalam persentase profits dibagi revenues. Rumusnya
#
#             ROUND((profits / revenues) * 100, 2)
#
# Buang terlebih dahulu profits dan revenues yang bernilai null

# %%
# %%sql
# SELECT
#     name,
#     sector,
#     revenues,
#     profits,
#     ROUND((profits::numeric / revenues) * 100, 2) AS profit_margin
# FROM fortune500
# WHERE profits IS NOT NULL
#   AND revenues IS NOT NULL
# ORDER BY profit_margin DESC
# LIMIT 10;
# Out:
#  * postgresql://mila:***@localhost:5432/training
# 10 rows affected.
# [('eBay Inc.', 'Technology', 8979, Decimal('7266'), Decimal('80.92')),
#  ('Altria Group, Inc.', 'Food, Beverages & Tobacco', 19337, Decimal('14239'), Decimal('73.64')),
#  ('Baxter International Inc.', 'Health Care', 10163, Decimal('4965'), Decimal('48.85')),
#  ('Reynolds American Inc.', 'Food, Beverages & Tobacco', 12503, Decimal('6073'), Decimal('48.57')),
#  ('Symantec Corporation', 'Technology', 5568, Decimal('2488'), Decimal('44.68')),
#  ('Gilead Sciences, Inc.', 'Health Care', 30390, Decimal('13501'), Decimal('44.43')),
#  ('Visa Inc.', 'Business Services', 15082, Decimal('5991'), Decimal('39.72')),
#  ('Corning Incorporated', 'Industrials', 9390, Decimal('3695'), Decimal('39.35')),
#  ('Mastercard Incorporated', 'Business Services', 10776, Decimal('4059'), Decimal('37.67')),
#  ('S&P Global Inc.', 'Business Services', 5661, Decimal('2106'), Decimal('37.20'))]

# %% [markdown]
# ### 13. Sektor mana yang paling efisien menghasilkan profit dibandingkan asetnya ?

# %% [markdown]
# Output yang ditampilkan adalah **sector, return_on_assets**

# %% [markdown]
# _**Petunjuk:**_
#
# **return_on_assets** adalah perbandingan antara profit dan asset. Hal ini untuk menunjukkan efisiensi operasional sektor, karena aset fisik lebih kecil tapi menghasilkan profit besar. Gunakan formula berikut untuk menghitung return_on_assets
#
#             ROUND(SUM(profits) / NULLIF(SUM(assets), 0) * 100, 2)

# %%
# %%sql
# SELECT
#     sector,
#     ROUND(SUM(profits) / NULLIF(SUM(assets), 0) * 100, 2) AS return_on_assets
# FROM fortune500
# WHERE profits IS NOT NULL
#   AND assets IS NOT NULL
# GROUP BY sector
# ORDER BY return_on_assets DESC
# LIMIT 1;
# Out:
#  * postgresql://mila:***@localhost:5432/training
# 1 rows affected.
# [('Apparel', Decimal('11.42'))]

# %% [markdown]
# ### 14. Kota mana yang paling banyak menjadi markas perusahaan Fortune 500?

# %% [markdown]
# Output yang ditampilkan adalah **hq dan total_companies**

# %% [markdown]
# _**Petunjuk:**_
#
# **hq** adalah kota yang dijadikan kantor utama bagi perusahaan.

# %%
# %%sql
# SELECT hq, COUNT(*) AS total_companies
# FROM fortune500
# GROUP BY hq
# ORDER BY total_companies DESC
# LIMIT 1;
# Out:
#  * postgresql://mila:***@localhost:5432/training
# 1 rows affected.
# [('New York, NY', 45)]

# %% [markdown]
# ### 15. Tampilkan 10 perusahaan yang memiliki struktur keuangan paling kuat (rasio equity/assets terbesar)?

# %% [markdown]
# Output yang ditampilkan adalah **title, sector dan equity_ratio**

# %% [markdown]
# _**Petunjuk:**_
#
# Perusahaan dengan **rasio equity** tinggi menunjukkan stabilitas keuangan dan ketergantungan rendah pada utang. Untuk menghitung rasio equity gunakan formula berikut:
#
#             ROUND((equity / NULLIF(assets, 0)) * 100, 2)

# %%
# %%sql
# SELECT
#     title,
#     sector,
#     ROUND((equity / NULLIF(assets, 0)) * 100, 2) AS equity_ratio
# FROM fortune500
# WHERE equity IS NOT NULL
#   AND assets IS NOT NULL
# ORDER BY equity_ratio DESC
# LIMIT 10;
# Out:
#  * postgresql://mila:***@localhost:5432/training
# 10 rows affected.
# [('Facebook', 'Technology', Decimal('91.12')),
#  ('Alphabet', 'Technology', Decimal('83.01')),
#  ('Publix Super Markets', 'Food & Drug Stores', Decimal('77.15')),
#  ('Cognizant Technology Solutions', 'Technology', Decimal('75.22')),
#  ('News Corp.', 'Media', Decimal('74.69')),
#  ('Franklin Resources', 'Financials', Decimal('74.14')),
#  ('Foot Locker', 'Retailing', Decimal('70.57')),
#  ('Hormel Foods', 'Food, Beverages & Tobacco', Decimal('69.83')),
#  ('Seaboard', 'Food, Beverages & Tobacco', Decimal('66.50')),
#  ('Baker Hughes', 'Energy', Decimal('66.49'))]

# %% [markdown]
# ### 16. Tampilkan 10 sektor dengan pertumbuhan pendapatan rata-rata tertinggi !

# %% [markdown]
# Output yang ditampilkan adalah **sector, dan avg_revenue_growth**

# %% [markdown]
# _**Petunjuk:**_
#
# avg_revenue_growth dihitung dengan menggunakan rata-rata revenues_change

# %%
# %%sql
# SELECT
#     sector,
#     ROUND(AVG(revenues_change)::numeric, 2) AS avg_revenue_growth
# FROM fortune500
# WHERE revenues_change IS NOT NULL
# GROUP BY sector
# ORDER BY avg_revenue_growth DESC
# LIMIT 10;
# Out:
#  * postgresql://mila:***@localhost:5432/training
# 10 rows affected.
# [('Telecommunications', Decimal('28.38')),
#  ('Food & Drug Stores', Decimal('22.27')),
#  ('Engineering & Construction', Decimal('13.37')),
#  ('Motor Vehicles & Parts', Decimal('11.30')),
#  ('Health Care', Decimal('10.22')),
#  ('Household Products', Decimal('8.77')),
#  ('Materials', Decimal('8.04')),
#  ('Technology', Decimal('7.16')),
#  ('Business Services', Decimal('5.59')),
#  ('Transportation', Decimal('5.48'))]

# %% [markdown]
# ### 17. Tampilkan 10 perusahaan dengan aset tertinggi !

# %% [markdown]
# Output yang ditampilkan adalah **title, sector, hq, assets**

# %%
# %%sql
# SELECT title, sector, hq, assets
# FROM fortune500
# WHERE assets IS NOT NULL
# ORDER BY assets DESC
# LIMIT 10;
# Out:
#  * postgresql://mila:***@localhost:5432/training
# 10 rows affected.
# [('Fannie Mae', 'Financials', 'Washington, DC', Decimal('3287968')),
#  ('J.P. Morgan Chase', 'Financials', 'New York, NY', Decimal('2490972')),
#  ('Bank of America Corp.', 'Financials', 'Charlotte, NC', Decimal('2187702')),
#  ('Freddie Mac', 'Financials', 'McLean, VA', Decimal('2023376')),
#  ('Wells Fargo', 'Financials', 'San Francisco, CA', Decimal('1930115')),
#  ('Citigroup', 'Financials', 'New York, NY', Decimal('1792077')),
#  ('MetLife', 'Financials', 'New York, NY', Decimal('898764')),
#  ('Goldman Sachs Group', 'Financials', 'New York, NY', Decimal('860165')),
#  ('Morgan Stanley', 'Financials', 'New York, NY', Decimal('814949')),
#  ('Prudential Financial', 'Financials', 'Newark, NJ', Decimal('783962'))]

# %% [markdown]
# ### 18. Hitung jumlah kelompok perusahaan small, medium and big
#
# Pengelompokkan tersebut berdasarkan perhitungan jumlah karyawan, dengan aturan sebagai berikut
# - SMALL --> jumlah karyawan lebih kecil atau sama dengan 200
# - MEDIUM --> jumlah karyawan lebih besar dari 200 dan lebih kecil atau sama dengan 1000
# - BIG --> jumlah karyawan lebih besar dari 1000
#
#
# ***Petunjuk***
# - gunakan case when
# - gunakan nested query (query di dalam query) untuk mengelompokkan

# %%
# %%sql
# SELECT category, COUNT(*) AS total_companies
# FROM (
#     SELECT
#         CASE
#             WHEN employees <= 200 THEN 'SMALL'
#             WHEN employees > 200 AND employees <= 1000 THEN 'MEDIUM'
#             ELSE 'BIG'
#         END AS category
#     FROM fortune500
#     WHERE employees IS NOT NULL
# ) AS sub
# GROUP BY category
# ORDER BY category;
# Out:
#  * postgresql://mila:***@localhost:5432/training
# 3 rows affected.
# [('BIG', 498), ('MEDIUM', 1), ('SMALL', 1)]

# %% [markdown]
# ### 19. Hitung rata-rata revenue per employee yang dikelompokkan berdasarkan sector
#
# Output yang ditampilkan **sector dan rev_per_employee**
#
# ***Petunjuk***
#
# Rata-rata revenue per employee --> avg(revenues/employees::numeric)

# %%
# %%sql
# SELECT
#     sector,
#     ROUND(AVG(revenues / employees::numeric), 2) AS rev_per_employee
# FROM fortune500
# WHERE revenues IS NOT NULL
#   AND employees IS NOT NULL
#   AND employees != 0
# GROUP BY sector
# ORDER BY rev_per_employee DESC;
# Out:
#  * postgresql://mila:***@localhost:5432/training
# 21 rows affected.
# [('Materials', Decimal('4.76')),
#  ('Energy', Decimal('1.83')),
#  ('Financials', Decimal('1.73')),
#  ('Wholesalers', Decimal('1.41')),
#  ('Engineering & Construction', Decimal('0.86')),
#  ('Food, Beverages & Tobacco', Decimal('0.83')),
#  ('Media', Decimal('0.80')),
#  ('Health Care', Decimal('0.79')),
#  ('Telecommunications', Decimal('0.63')),
#  ('Chemicals', Decimal('0.60')),
#  ('Technology', Decimal('0.57')),
#  ('Business Services', Decimal('0.42')),
#  ('Transportation', Decimal('0.40')),
#  ('Aerospace & Defense', Decimal('0.37')),
#  ('Industrials', Decimal('0.36')),
#  ('Retailing', Decimal('0.36')),
#  ('Household Products', Decimal('0.36')),
#  ('Motor Vehicles & Parts', Decimal('0.34')),
#  ('Food & Drug Stores', Decimal('0.31')),
#  ('Apparel', Decimal('0.28')),
#  ('Hotels, Restaurants & Leisure', Decimal('0.09'))]

# %% [markdown]
# ### 20. Tampilkan 5 industri yang memiliki keuntungan negatif (rugi) paling banyak?
#
# Output yang ditampilkan **industry dan num_companies**

# %%
# %%sql
# SELECT
#     industry,
#     COUNT(*) AS num_companies
# FROM fortune500
# WHERE profits < 0
# GROUP BY industry
# ORDER BY num_companies DESC
# LIMIT 5;
# Out:
#  * postgresql://mila:***@localhost:5432/training
# 5 rows affected.
# [('Mining, Crude-Oil Production', 8),
#  ('Petroleum Refining', 3),
#  ('Oil and Gas Equipment, Services', 3),
#  ('Health Care: Medical Facilities', 3),
#  ('Specialty Retailers: Other', 3)]

# %% [markdown]
# # JIKA SUDAH SELESAI, JANGAN LUPA DISAVE #
